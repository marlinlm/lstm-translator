# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
def show_loss(loss_fname, min_steps = 0, max_steps = 0, offset = 0, scaler = 1):
    loss_out_file=loss_fname
    x=[]
    y=[]
    y_1=[]
    y_2=[]
    idx = 0
    dev=[]
    k=800
    k_2=100
    step = 0
    with open(loss_out_file, 'r', encoding='utf-8') as ff:
        for line in ff.readlines():
            step += 1
            
            if min_steps != 0 and min_steps > step:
                continue
          
            if max_steps != 0 and step >= max_steps:
                break
            token = line.split(',')
            y.append(float(token[3][:-1]) * scaler)
            x.append(idx)
            idx += 1
            _y = y[-k:]
            _y_2 = y[-k_2:]
            
#             if len(_y) >= k:
#                 y_1.append(np.median(_y))
#             else:
#                 y_1.append(None)
            
#             if len(_y_2) >= k_2:
#                 dev.append(np.std(_y_2))
#                 y_2.append(np.median(_y_2))
#             else:
#                 y_2.append(None)
    
            y_1.append(np.mean(_y))

            dev.append(np.std(_y_2))
            y_2.append(np.mean(_y_2))
                
    # plt.plot(x,y,'.',label='raw')
    plt.plot(x[offset:],y_2[offset:],'.',label=f'{k_2}-mean')
    plt.plot(x[offset:],y_1[offset:],'.',label=f'{k}-mean')
    plt.xlabel('iter')
    plt.ylabel('losses')
    plt.title('losses')
    plt.legend(loc=9)
    plt.grid(True)
    plt.show()
    print(str(step), str(y_1[-1]), str(y_2[-1]))
#     plt.plot(x,dev,'.',label='dev')
#     plt.xlabel('steps')
#     plt.ylabel('dev')
#     plt.title('dev')
#     plt.legend(loc=9)
#     plt.grid(True)
#     plt.show()
    
    # plt.plot(x,y,'.',label='raw')
    # plt.xlabel('iter')
    # plt.ylabel('losses')
    # plt.title('losses')
    # plt.legend(loc=9)
    # plt.grid(True)
    # plt.show()
    return step

start = 0
cast_start = 50
step = show_loss("../loss.log",start, 0, cast_start)
show_loss("../loss.adam",start, 0, cast_start)
show_loss("../loss.log_13",start, 0, cast_start)
# show_loss("../loss.log_2",5000)
# Out:
# 4335 0.0040529349898068175 0.003908939131523948
# 4591 0.004164780585721018 0.0040979807425756
# 8358 0.016927273954876 0.01729605168616399
# 8358

# %%
from seq2seq import Seq2Seq
from torchinfo import summary
import torch
device = torch.device('cpu')
embeddings = 300
hiddens = 900
n_layers = 4

model = Seq2Seq(device, embeddings, hiddens, n_layers, 0.5, 0.5).to(device)
summary(model, input_size=[(1, 10, 300),(1,10,300)])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Seq2Seq                                  [1, 11, 300]              --
# ├─Encoder: 1-1                           [1, 10, 300]              --
# │    └─LSTM: 2-1                         [1, 10, 900]              23,788,800
# │    └─Linear: 2-2                       [1, 10, 300]              270,300
# │    └─Tanhshrink: 2-3                   [1, 10, 300]              --
# ├─Decoder: 1-2                           [1, 11, 300]              --
# │    └─LSTM: 2-4                         [1, 11, 900]              23,788,800
# │    └─Linear: 2-5                       [1, 11, 300]              270,300
# │    └─Tanhshrink: 2-6                   [1, 11, 300]              --
# ==========================================================================================
# Total params: 48,118,200
# Trainable params: 48,118,200
# Non-trainable params: 0
# Total mult-adds (M): 500.11
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.20
# Params size (MB): 192.47
# Estimated Total Size (MB): 192.70
# ==========================================================================================
