# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
def show_loss(loss_fname, min_steps = 0, max_steps = 0, offset = 0, scaler = 1):
    loss_out_file=loss_fname
    x=[]
    y=[]
    y_1=[]
    y_2=[]
    idx = 0
    dev=[]
    k=500
    k_2=1
    step = 0
    with open(loss_out_file, 'r', encoding='utf-8') as ff:
        for line in ff.readlines():
            step += 1
            
            if min_steps != 0 and min_steps > step:
                continue
          
            if max_steps != 0 and step >= max_steps:
                break
            token = line.split(',')
            y.append(float(token[3][:-1]) * scaler)
            x.append(idx)
            idx += 1
            _y = y[-k:]
            _y_2 = y[-k_2:]
            
            y_1.append(np.mean(_y))

            dev.append(np.std(_y_2))
            y_2.append(np.mean(_y_2))
                
    # plt.plot(x,y,'.',label='raw')
    plt.plot(x[offset:],y_2[offset:],'.',label=f'{k_2}-mean')
    plt.plot(x[offset:],y_1[offset:],'.',label=f'{k}-mean')
    plt.xlabel('iter')
    plt.ylabel('losses')
    plt.title('losses')
    plt.legend(loc=9)
    plt.grid(True)
    plt.show()
    print(str(step), str(y_1[-1]), str(y_2[-1]))
    return step

start = 0
cast_start = 100
step = show_loss("../loss.log",start, 0, cast_start)
# Out:
# 110882 1.948659874677658 1.744625449180603

# %%
def show_loss_2(loss_fname, min_steps = 0, max_steps = 0, offset = 0, scaler = 1):
    loss_out_file=loss_fname
    x=[]
    y=[]
    y_1=[]
    y_2=[]
    idx = 0
    dev=[]
    window=5000
    step = 0
    with open(loss_out_file, 'r', encoding='utf-8') as ff:
        for line in ff.readlines():
            step += 1
            
            if min_steps != 0 and min_steps > step:
                continue
          
            if max_steps != 0 and step >= max_steps:
                break
            token = line.split(',')
            y.append(float(token[3][:-1]) * scaler)
            
            
            if step % window == (window - 1):
                x.append(idx)
                idx += 1
                y_1.append(np.mean(y))
                y = []
            
                
    # plt.plot(x,y,'.',label='raw')
    plt.plot(x[offset:],y_1[offset:],'.',label=f'{window}-mean')
    plt.xlabel('iter')
    plt.ylabel('losses')
    plt.title('losses')
    plt.legend(loc=9)
    plt.grid(True)
    plt.show()
#     plt.plot(x,dev,'.',label='dev')
#     plt.xlabel('steps')
#     plt.ylabel('dev')
#     plt.title('dev')
#     plt.legend(loc=9)
#     plt.grid(True)
#     plt.show()
    
    # plt.plot(x,y,'.',label='raw')
    # plt.xlabel('iter')
    # plt.ylabel('losses')
    # plt.title('losses')
    # plt.legend(loc=9)
    # plt.grid(True)
    # plt.show()
    return step

start = 0
cast_start = 0
step = show_loss_2("../loss.log",start, 0, cast_start)

# %%
def show_loss_3(loss_fname, min_steps = 0, max_steps = 0, offset = 0, scaler = 1):
    loss_out_file=loss_fname
    x=[]
    y=[]
    y_1=[]
    y_2=[]
    idx = 0
    dev=[]
    window=5000
    off_set = 2000
    step = 0
    with open(loss_out_file, 'r', encoding='utf-8') as ff:
        for line in ff.readlines():
            step += 1
            
            if min_steps != 0 and min_steps > step:
                continue
          
            if max_steps != 0 and step >= max_steps:
                break
            token = line.split(',')
            y.append(float(token[3][:-1]) * scaler)
            
            
            if step % window == (window - 1):
                x.append(idx)
                idx += 1
                y_1.append(y[off_set])
                print(str(y[off_set]))
                print(str(len(y)))
                y = []
            
                
    # plt.plot(x,y,'.',label='raw')
    plt.plot(x[offset:],y_1[offset:],'.',label=f'{window}-mean')
    plt.xlabel('iter')
    plt.ylabel('losses')
    plt.title('losses')
    plt.legend(loc=9)
    plt.grid(True)
    plt.show()
#     plt.plot(x,dev,'.',label='dev')
#     plt.xlabel('steps')
#     plt.ylabel('dev')
#     plt.title('dev')
#     plt.legend(loc=9)
#     plt.grid(True)
#     plt.show()
    
    # plt.plot(x,y,'.',label='raw')
    # plt.xlabel('iter')
    # plt.ylabel('losses')
    # plt.title('losses')
    # plt.legend(loc=9)
    # plt.grid(True)
    # plt.show()
    return step

start = 0
cast_start = 0
step = show_loss_3("../loss.log",start, 0, cast_start)
# Out:
# 2.251149892807007
# 4999
# 2.2285943031311035
# 5000
# 2.2256736755371094
# 5000
# 2.243374824523926
# 5000
# 2.113614797592163
# 5000
# 2.117795467376709
# 5000
# 2.0997815132141113
# 5000
