# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
def show_loss(loss_fname, min_steps = 0, max_steps = 0, offset = 0, scaler = 1):
    loss_out_file=loss_fname
    x=[]
    y=[]
    y_1=[]
    y_2=[]
    idx = 0
    dev=[]
    k=500
    k_2=100
    step = 0
    with open(loss_out_file, 'r', encoding='utf-8') as ff:
        for line in ff.readlines():
            step += 1
            
            if min_steps != 0 and min_steps > step:
                continue
          
            if max_steps != 0 and step >= max_steps:
                break
            token = line.split(',')
            y.append(float(token[3][:-1]) * scaler)
            x.append(idx)
            idx += 1
            _y = y[-k:]
            _y_2 = y[-k_2:]
            
            y_1.append(np.mean(_y))

            dev.append(np.std(_y_2))
            y_2.append(np.mean(_y_2))
                
    # plt.plot(x,y,'.',label='raw')
    plt.plot(x[offset:],y_2[offset:],'.',label=f'{k_2}-mean')
    plt.plot(x[offset:],y_1[offset:],'.',label=f'{k}-mean')
    plt.xlabel('iter')
    plt.ylabel('losses')
    plt.title('losses')
    plt.legend(loc=9)
    plt.grid(True)
    plt.show()
    print(str(step), str(y_1[-1]), str(y_2[-1]))
    return step

start = 0
cast_start = 5000
cast_end = 0
step = show_loss("./loss/20231124_200_500000_100.loss",start, cast_end, cast_start)
# Out:
# 78629 185.863958114624 179.94560340881347

# %%
def show_loss_2(loss_fname, min_steps = 0, max_steps = 0, offset = 0, scaler = 1):
    loss_out_file=loss_fname
    x=[]
    y=[]
    y_1=[]
    y_2=[]
    idx = 0
    dev=[]
    window=5000
    step = 0
    with open(loss_out_file, 'r', encoding='utf-8') as ff:
        for line in ff.readlines():
            step += 1
            
            if min_steps != 0 and min_steps > step:
                continue
          
            if max_steps != 0 and step >= max_steps:
                break
            token = line.split(',')
            y.append(float(token[3][:-1]) * scaler)
            
            
            if step % window == (window - 1):
                x.append(idx)
                idx += 1
                y_1.append(np.mean(y))
                y = []
            
                
    # plt.plot(x,y,'.',label='raw')
    plt.plot(x[offset:],y_1[offset:],'.',label=f'{window}-mean')
    plt.xlabel('iter')
    plt.ylabel('losses')
    plt.title('losses')
    plt.legend(loc=9)
    plt.grid(True)
    plt.show()
#     plt.plot(x,dev,'.',label='dev')
#     plt.xlabel('steps')
#     plt.ylabel('dev')
#     plt.title('dev')
#     plt.legend(loc=9)
#     plt.grid(True)
#     plt.show()
    
    # plt.plot(x,y,'.',label='raw')
    # plt.xlabel('iter')
    # plt.ylabel('losses')
    # plt.title('losses')
    # plt.legend(loc=9)
    # plt.grid(True)
    # plt.show()
    return step

start = 0
cast_start = 0
step = show_loss_2("./loss/20231124_200_500000_100.loss",start, 0, cast_start)

# %%
def show_loss_3(loss_fname, min_steps = 0, max_steps = 0, offset = 0, scaler = 1):
    loss_out_file=loss_fname
    x=[]
    y=[]
    y_1=[]
    y_2=[]
    idx = 0
    dev=[]
    window=5000
    off_set = 1170
    step = 0
    with open(loss_out_file, 'r', encoding='utf-8') as ff:
        for line in ff.readlines():
            step += 1
            
            if min_steps != 0 and min_steps > step:
                continue
          
            if max_steps != 0 and step >= max_steps:
                break
            token = line.split(',')
            y.append(float(token[3][:-1]) * scaler)
            
            
            if step % window == (window - 1):
                x.append(idx)
                idx += 1
                y_1.append(y[off_set])
                print(str(y[off_set]))
                print(str(len(y)))
                y = []
            
                
    # plt.plot(x,y,'.',label='raw')
    plt.plot(x[offset:],y_1[offset:],'.',label=f'{window}-mean')
    plt.xlabel('iter')
    plt.ylabel('losses')
    plt.title('losses')
    plt.legend(loc=9)
    plt.grid(True)
    plt.show()
#     plt.plot(x,dev,'.',label='dev')
#     plt.xlabel('steps')
#     plt.ylabel('dev')
#     plt.title('dev')
#     plt.legend(loc=9)
#     plt.grid(True)
#     plt.show()
    
    # plt.plot(x,y,'.',label='raw')
    # plt.xlabel('iter')
    # plt.ylabel('losses')
    # plt.title('losses')
    # plt.legend(loc=9)
    # plt.grid(True)
    # plt.show()
    return step

start = 10000
cast_start = 0
step = show_loss_3("../loss.log",start, 0, cast_start)
# Out:
# 2.0943074226379395
# 5000
# 2.063469409942627
# 5000
# 1.9927499294281006
# 5000
# 1.9469363689422607
# 5000
# 1.98332941532135
# 5000
# 1.944349765777588
# 5000
# 1.9469302892684937
# 5000
# 1.9445445537567139
# 5000
# 1.9118399620056152
# 5000
# 1.9623113870620728
# 5000
# 1.8795537948608398
# 5000
# 1.891211986541748
# 5000
# 1.864770770072937
# 5000
# 1.8712939023971558
# 5000
# 1.8913612365722656
# 5000
# 1.851620078086853
# 5000
# 1.9052517414093018
# 5000
# 1.8581345081329346
# 5000
# 1.8709474802017212
# 5000
# 1.8542605638504028
# 5000
# 1.8712942600250244
# 5000
# 1.864691138267517
# 5000
# 1.8409850597381592
# 5000
# 1.8134291172027588
# 5000
# 1.819671630859375
# 5000
# 1.8377292156219482
# 5000
# 1.8259773254394531
# 5000
# 1.8049705028533936
# 5000
# 1.8082342147827148
# 5000
# 1.833611011505127
# 5000
# 1.8449814319610596
# 5000
# 1.8134126663208008
# 5000
# 1.8215217590332031
# 5000
# 1.7816219329833984
# 5000
# 1.8223762512207031
# 5000
# 1.7771694660186768
# 5000
# 1.8124592304229736
# 5000
# 1.813403844833374
# 5000
# 1.8135461807250977
# 5000
# 1.8130131959915161
# 5000
# 1.7753561735153198
# 5000
# 1.8013101816177368
# 5000
# 1.819548487663269
# 5000
# 1.8122544288635254
# 5000
# 1.7971501350402832
# 5000
# 1.765274167060852
# 5000
# 1.7168341875076294
# 5000
# 1.6886430978775024
# 5000
# 1.6912455558776855
# 5000
# 1.6746165752410889
# 5000
# 1.6760473251342773
# 5000
# 1.674957275390625
# 5000
# 1.6584968566894531
# 5000
# 1.6582425832748413
# 5000
# 1.6596671342849731
# 5000
# 1.6213014125823975
# 5000
# 1.6460602283477783
# 5000
# 1.6428545713424683
# 5000
# 1.6146304607391357
# 5000
# 1.619802474975586
# 5000
# 1.6397960186004639
# 5000
# 1.635076642036438
# 5000
# 1.6421037912368774
# 5000
